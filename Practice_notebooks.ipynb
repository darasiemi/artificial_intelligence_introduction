# %%
class Graph ():
    def __init__(edges, num_nodes):
        self.num_nodes = []*num_nodes

# %%
def depth_first_search(graph, node, visited=None):
    if visited is None:
        visited = set()  
    if node not in visited:
        print(node, end=" ")  
        visited.add(node) 
        
        for neighbor in graph[node]:
            if neighbor not in visited:
                depth_first_search(graph, neighbor, visited)

# Example Graph represented as an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

depth_first_search(graph, 'A')
# Out:
# A B D E F C

# %%
class Graph:
    def __init__(self):
        self.graph = {}

    def add_vertex(self, vertex):
        if vertex not in self.graph:
            self.graph[vertex] = []

    def add_edge(self, vertex, neighbor):
        if vertex in self.graph and neighbor in self.graph:
            self.graph[vertex].append(neighbor)

    def dfs(self, start_vertex):
        visited = set() 
        self._dfs_recursive(start_vertex, visited)

    def _dfs_recursive(self, vertex, visited):
        if vertex not in visited:
            print(vertex, end=" ")  
            visited.add(vertex)  
           
            for neighbor in self.graph[vertex]:
                if neighbor not in visited:
                    self._dfs_recursive(neighbor, visited)


g = Graph()


vertices = ['A', 'B', 'C', 'D', 'E', 'F']
for v in vertices:
    g.add_vertex(v)

# Adding edges (connections between nodes)
g.add_edge('A', 'B')
g.add_edge('A', 'C')
g.add_edge('B', 'D')
g.add_edge('B', 'E')
g.add_edge('C', 'F')
g.add_edge('E', 'F')

# Perform DFS traversal starting from vertex 'A'
g.dfs('A')
# Out:
# A B D E F C

# %%
def BFS(g, s, discovered):
    
    level = [s]  # The current level of vertices (starting with the source vertex s)
    
    while len(level) > 0:
        next_level = []  # To store the vertices for the next level in the BFS tree
        for u in level:
            for e in g.incident_edges(u):  # Get all incident edges of vertex u
                v = e.opposite(u)  # Get the opposite vertex of u on edge e
                if v not in discovered:  # If vertex v has not been discovered
                    discovered[v] = e  # The edge e is how we discovered v
                    next_level.append(v)  # Add vertex v to the next level
        
        level = next_level  # Move to the next level of the graph
        
class Vertex:
    def __init__(self, element):
        self.element = element  # Store element (or label) for vertex

    def __repr__(self):
        return str(self.element)  # Return the string representation of the vertex

class Edge:
    def __init__(self, u, v):
        self.origin = u
        self.destination = v

    def opposite(self, vertex):
        """Return the vertex that is opposite to vertex on this edge."""
        if vertex == self.origin:
            return self.destination
        elif vertex == self.destination:
            return self.origin
        else:
            raise ValueError("vertex not part of this edge")

class Graph:
    def __init__(self):
        self._outgoing = {}

    def add_vertex(self, element):
        v = Vertex(element)
        self._outgoing[v] = []
        return v

    def add_edge(self, u, v):
        e = Edge(u, v)
        self._outgoing[u].append(e)
        self._outgoing[v].append(e)

    def incident_edges(self, v):
        """Return all edges incident to vertex v."""
        return self._outgoing[v]


g = Graph()


vertices = ['A', 'B', 'C', 'D', 'E', 'F']
for v in vertices:
    g.add_vertex(v)

# Adding edges (connections between nodes)
g.add_edge('A', 'B')
g.add_edge('A', 'C')
g.add_edge('B', 'D')
g.add_edge('B', 'E')
g.add_edge('C', 'F')
g.add_edge('E', 'F')

# Discover BFS from vertex A
discovered = {v1: None}
BFS(g, v1, discovered)

# Print discovered nodes and the edges that discovered them
for vertex, edge in discovered.items():
    if edge is not None:
        print(f"Vertex {vertex} was discovered via edge from {edge.origin} to {edge.destination}")
    else:
        print(f"Vertex {vertex} is the start vertex")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 64
#      61     g.add_vertex(v)
#      63 # Adding edges (connections between nodes)
# ---> 64 g.add_edge('A', 'B')
#      65 g.add_edge('A', 'C')
#      66 g.add_edge('B', 'D')
#
# Cell In[5], line 48, in Graph.add_edge(self, u, v)
#      46 def add_edge(self, u, v):
#      47     e = Edge(u, v)
# ---> 48     self._outgoing[u].append(e)
#      49     self._outgoing[v].append(e)
#
# KeyError: 'A'
